# %% [markdown]
# # Nobel prizes

# %% [markdown]
# ## 1. Loading the data
# <p><img style="float: right;margin:5px 20px 5px 1px; max-width:250px" src="https://s3.amazonaws.com/assets.datacamp.com/production/project_441/img/Nobel_Prize.png"></p>
# <p>The Nobel Prize is perhaps the world's most well known scientific award. Except for the honor, prestige and substantial prize money the recipient also gets a gold medal showing Alfred Nobel (1833 - 1896) who established the prize. Every year it's given to scientists and scholars in the categories chemistry, literature, physics, physiology or medicine, economics, and peace. The first Nobel Prize was handed out in 1901, and at that time the Prize was very Eurocentric and male-focused, but nowadays it's not biased in any way whatsoever. Surely. Right?</p>
# <p>Well, we're going to find out! The Nobel Foundation has made a dataset available of all prize winners from the start of the prize, in 1901, to 2016. Let's load it in and take a look.</p>

# %%
# Loading in required libraries: you will need pandas, seaborn and numpy
import numpy as np
import matplotlib as plot
import seaborn as sns
import pandas as pd
# Reading in the Nobel Prize data
nobel =pd.read_csv('datasets/nobel.csv')
# Explore the data - are there missing values? How many entries do we have?
nobel
# Out:
#      year    category                                              prize  \
# 0    1901   Chemistry                  The Nobel Prize in Chemistry 1901
# 1    1901  Literature                 The Nobel Prize in Literature 1901
# 2    1901    Medicine     The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                         The Nobel Peace Prize 1901
# 4    1901       Peace                         The Nobel Peace Prize 1901
# 5    1901     Physics                    The Nobel Prize in Physics 1901
# 6    1902   Chemistry                  The Nobel Prize in Chemistry 1902
# 7    1902  Literature                 The Nobel Prize in Literature 1902
# 8    1902    Medicine     The Nobel Prize in Physiology or Medicine 1902
# 9    1902       Peace                         The Nobel Peace Prize 1902
# 10   1902       Peace                         The Nobel Peace Prize 1902
# 11   1902     Physics                    The Nobel Prize in Physics 1902
# ...

# %% [markdown]
# At first glance the dataset is missing 852 values from the years 1905 to 2014. However when inspecting the data carefully it is clear that these values are not missing but are "hidden" so that the dataset can be displayed.

# %% [markdown]
# ## 2. So, who gets the Nobel Prize?
# <p>Just looking at the first couple of prize winners, or Nobel laureates as they are also called, we already see a celebrity: Wilhelm Conrad Röntgen, the guy who discovered X-rays. And actually, we see that all of the winners in 1901 were guys that came from Europe. But that was back in 1901, looking at all winners in the dataset, from 1901 to 2016, which sex and which country is the most commonly represented? </p>
# <p>(For <em>country</em>, we will use the <code>birth_country</code> of the winner, as the <code>organization_country</code> is <code>NaN</code> for all shared Nobel Prizes.)</p>

# %%
# Display the number of (possibly shared) Nobel Prizes handed
# out between 1901 and 2016
print(len(nobel))
# Display the number of prizes won by male and female recipients.
print(nobel["sex"].value_counts())

# Display the number of prizes won by the top 10 nationalities.
nobel["birth_country"].value_counts().head(10)
# Out:
# 911
# Male      836
# Female     49
# Name: sex, dtype: int64
# United States of America    259
# United Kingdom               85
# Germany                      61
# France                       51
# Sweden                       29
# Japan                        24
# Netherlands                  18
# Canada                       18
# Italy                        17
# Russia                       17
# Name: birth_country, dtype: int64

# %% [markdown]
# Males have been most commonly represented accounting for 91.77% of the awards won while females account for 5.38% and organisations account for 2.85%. The most commonly representes country is the United States of America despite the Nobel Prize being founded in Euroupe, the United States of America accounts for 28.43% of the awards won.

# %% [markdown]
# ## 3. USA dominance
# <p>Not so surprising perhaps: the most common Nobel laureate between 1901 and 2016 was a man born in the United States of America. But in 1901 all the winners were European. When did the USA start to dominate the Nobel Prize charts?</p>

# %%
# Calculating the proportion of USA born winners per decade
nobel['usa_born_winner'] = nobel["birth_country"] == "United States of America"
nobel['decade'] = (np.floor(nobel["year"]/10)*10).astype(int)
prop_usa_winners = nobel.groupby("decade", as_index=False)["usa_born_winner"].mean()

# Display the proportions of USA born winners per decade
prop_usa_winners
# Out:
#     decade  usa_born_winner
# 0     1900         0.017544
# 1     1910         0.075000
# 2     1920         0.074074
# 3     1930         0.250000
# 4     1940         0.302326
# 5     1950         0.291667
# 6     1960         0.265823
# 7     1970         0.317308
# 8     1980         0.319588
# 9     1990         0.403846
# 10    2000         0.422764
# 11    2010         0.292683

# %% [markdown]
# The United States of America started to dominate the Nobel Prize charts in the 1930 as this is the point that the USA had won 25% of the awards.

# %% [markdown]
# ## 4. USA dominance, visualized
# <p>A table is OK, but to <em>see</em> when the USA started to dominate the Nobel charts we need a plot!</p>

# %%
#using seaborn, plot the proportion of US winners by decade
sns.set()
nobel['usa_born_winner'] = nobel["birth_country"] == "United States of America"
nobel['decade'] = (np.floor(nobel["year"] / 10) * 10).astype(int)
ax = sns.pointplot(x=nobel['decade'], y=nobel['usa_born_winner'],color="purple")
ax.set_title('Proportion of USA Winners per Decade')
# Out:
# Text(0.5, 1.0, 'Proportion of USA Winners per Decade')

# %% [markdown]
# There was an increase in the number of USA born winners from 1920 to 1930, the amount steadily increased and decreased over the next 50 years but increased significantly once again between 1980 and 1990 and continued to increase however there was a sharp decline in those numbers from 2000 to 2010.

# %% [markdown]
# ## 5. What is the gender of a typical Nobel Prize winner?
# <p>So the USA became the dominating winner of the Nobel Prize first in the 1930s and had kept the leading position ever since. But one group that was in the lead from the start, and never seems to let go, are <em>men</em>. Maybe it shouldn't come as a shock that there is some imbalance between how many male and female prize winners there are, but how significant is this imbalance? And is it better or worse within specific prize categories like physics, medicine, literature, etc.?</p>

# %%
# Calculating the proportion of female laureates per decade
nobel['female_winner'] = nobel["sex"] == "Female"
nobel['decade'] = (np.floor(nobel["year"] / 10) * 10).astype(int)
prop_female_winners = nobel.groupby(["decade", "category"], as_index=False)["female_winner"].mean()

# Plot proportion of female winners by decade, grouped by prize category (physics, medicine, etc)
ax = sns.barplot(x="decade", y="female_winner", hue="category", data=prop_female_winners)
ax.set_title("Female Winners Per Decade by Catergory")
# Out:
# Text(0.5, 1.0, 'Female Winners Per Decade by Catergory')

# %% [markdown]
# The plot shows how the number of female winners has increased from the Nobel Prize inception. Females have many contributed to the fields of literature and peace as these categories have the highest numbers of female winners however this is reletive to the time periods in which females recieve the awards as well as the conditions of the world at that time. The most significant finding is that no female won the award during the 1950s.

# %% [markdown]
# ## 6. The first woman to win the Nobel Prize
# <p>The plot above is a bit messy as the lines are overplotting. But it does show some interesting trends and patterns. Overall the imbalance is pretty large with physics, economics, and chemistry having the largest imbalance. Medicine has a somewhat positive trend, and since the 1990s the literature prize is also now more balanced. The big outlier is the peace prize during the 2010s, but keep in mind that this just covers the years 2010 to 2016.</p>
# <p>Given this imbalance, who was the first woman to receive a Nobel Prize? And in what category?</p>

# %%
# Picking out the first woman to win a Nobel Prize
ff1 = nobel[nobel["sex"] == "Female"]
ff1.nsmallest(1, "year")
# Out:
#     year category                            prize  \
# 19  1903  Physics  The Nobel Prize in Physics 1903
#
#                                            motivation prize_share  \
# 19  "in recognition of the extraordinary services ...         1/4
#
#     laureate_id laureate_type                    full_name  birth_date  \
# 19            6    Individual  Marie Curie, née Sklodowska  1867-11-07
#
#    birth_city            birth_country     sex organization_name  \
# 19     Warsaw  Russian Empire (Poland)  Female               NaN
#
#    organization_city organization_country  death_date  death_city  \
# 19               NaN                  NaN  1934-07-04  Sallanches
#
#    death_country
# 19        France

# %% [markdown]
# The first woman to win the Nobel Prize was Marie Curie. She won the Nobel Prize in Physics in 1903.

# %% [markdown]
# ## 7. Repeat laureates
# <p>For most scientists/writers/activists a Nobel Prize would be the crowning achievement of a long career. But for some people, one is just not enough, and few have gotten it more than once. Who are these lucky few? (Having won no Nobel Prize myself, I'll assume it's just about luck.)</p>

# %%
# Selecting the laureates that have received 2 or more prizes.
new_df = nobel.groupby('full_name').filter(lambda x: len(x)>=2)
new_df['full_name'].value_counts()
# Out:
# Comité international de la Croix Rouge (International Committee of the Red Cross)    3
# Frederick Sanger                                                                     2
# John Bardeen                                                                         2
# Linus Carl Pauling                                                                   2
# Office of the United Nations High Commissioner for Refugees (UNHCR)                  2
# Marie Curie, née Sklodowska                                                          2
# Name: full_name, dtype: int64

# %% [markdown]
# There are 6 award winners who have recieved the prize twice or more. The award winners are Marie Curie, Comité international de la Croix Rouge(International Committee of the Red Cross),Linus Pauling, Office of the United Nations High Commissioner for Refugees, John Bardeen and Frederick Sanger.

# %% [markdown]
# ## 8. How old are you when you get the prize?
# <p>The list of repeat winners contains some illustrious names! We again meet Marie Curie, who got the prize in physics for discovering radiation and in chemistry for isolating radium and polonium. John Bardeen got it twice in physics for transistors and superconductivity, Frederick Sanger got it twice in chemistry, and Linus Carl Pauling got it first in chemistry and later in peace for his work in promoting nuclear disarmament. We also learn that organizations also get the prize as both the Red Cross and the UNHCR have gotten it twice.</p>
# <p>But how old are you generally when you get the prize?</p>

# %%
# Converting birth_date from String to datetime
nobel['birth_date'] = pd.to_datetime(nobel["birth_date"])

# Calculating the age of Nobel Prize winners
nobel['age'] = nobel["year"] - nobel["birth_date"].dt.year

# What is the mean age of winners and it's standard devation? What is the median age?
nobel['age'].describe()
# Out:
# count    883.000000
# mean      59.453001
# std       12.399290
# min       17.000000
# 25%       50.000000
# 50%       60.000000
# 75%       69.000000
# max       90.000000
# Name: age, dtype: float64

# %% [markdown]
# Winning a Nobel Prize can happen at any age however the average age of Nobel laureates is 59.5. This means that the general age to receieve the Nobel Prize is between 47 and 72.

# %% [markdown]
# ## 9. Age differences between prize categories

# %%
#Plot the age of nobel candidates by decade
nobel['decade'] = (np.floor(nobel["year"] / 10) * 10).astype(int)
nobel['age'] = nobel["year"] - nobel["birth_date"].dt.year
ag= sns.swarmplot(x=nobel['decade'], y=nobel['age'])
ag.set_title("Age Of Nobel Prize Winners per Decade")
# Out:
# Text(0.5, 1.0, 'Age Of Nobel Prize Winners per Decade')

# %%
# Plot the age of nobel candidates by decade and prize category
agc= sns.barplot(x=nobel['decade'], y=nobel['age'], hue="category", data= nobel)
agc.set_title("Age Of Nobel Prize Winners per Decade by Category")

# %% [markdown]
# Over the last 60 years the has been a drop in the age of Nobel Prize winners. The data shows that awards for peace, economics and literature are generally given at older ages while awards for chemsitry, medicine and physics are given at slightly younger ages. These general assumptions have however been overturned in the decade and may set a president for younger Nobel Prize winners.

# %% [markdown]
# ## 10. Oldest and youngest winners
# <p>In the peace category there is a winner around 2010 that seems exceptionally young. This begs the questions, who are the oldest and youngest people ever to have won a Nobel Prize?</p>

# %%
nobel.nlargest(1, "age")
# Out:
#      year   category                                              prize  \
# 793  2007  Economics  The Sveriges Riksbank Prize in Economic Scienc...
#
#                                             motivation prize_share  \
# 793  "for having laid the foundations of mechanism ...         1/3
#
#      laureate_id laureate_type       full_name birth_date birth_city  ...  \
# 793          820    Individual  Leonid Hurwicz 1917-08-21     Moscow  ...
#
#       sex        organization_name organization_city  \
# 793  Male  University of Minnesota   Minneapolis, MN
#
#          organization_country  death_date       death_city  \
# 793  United States of America  2008-06-24  Minneapolis, MN
#
#                 death_country female_winner  decade   age
# 793  United States of America         False    2000  90.0
#
# [1 rows x 21 columns]

# %%
nobel.nsmallest(1, "age")
# Out:
#      year category                       prize  \
# 885  2014    Peace  The Nobel Peace Prize 2014
#
#                                             motivation prize_share  \
# 885  "for their struggle against the suppression of...         1/2
#
#      laureate_id laureate_type         full_name birth_date birth_city  ...  \
# 885          914    Individual  Malala Yousafzai 1997-07-12    Mingora  ...
#
#         sex organization_name organization_city organization_country  \
# 885  Female               NaN               NaN                  NaN
#
#     death_date death_city death_country female_winner  decade   age
# 885        NaN        NaN           NaN          True    2010  17.0
#
# [1 rows x 21 columns]

# %% [markdown]
# The oldest person to win the Nobel Prize is Leonid Hurwicz, who won the prize at the age of 90. The youngest person to win the Nobel Prize is Malala Yousafzai, she was awarded the prize at the age of 17.

# %% [markdown]
# ## Congratulations! You've reached the end of the challenge!
